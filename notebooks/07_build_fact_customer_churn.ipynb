# %% [markdown]
# # Build fact_customer_churn
#
# Purpose:
# - Create a snapshot-based churn fact table at customer grain
# - Combine churn outcomes with revenue and lifecycle measures
# - Enable time-based churn and revenue impact analysis

# %%
import pandas as pd
import numpy as np

data_path = "../data/raw/"

customer = pd.read_excel(data_path + "CustomerChurn.xlsx")
services = pd.read_excel(data_path + "Telco_customer_churn_services.xlsx")
status = pd.read_excel(data_path + "Telco_customer_churn_status.xlsx")

# %%
customer.shape, services.shape, status.shape
# Out:
# ((7043, 21), (7043, 31), (7043, 12))

# %%
fact_status = status[
    ["Customer ID", "Quarter", "Churn Value"]
].copy()

fact_status.columns = [
    "customer_id",
    "quarter",
    "churned"
]

# %%
fact_status["customer_id"].nunique()
fact_status["churned"].value_counts()
# Out:
# churned
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
def quarter_end_date(q):
    q = q.strip()
    quarter, year = q.split()
    year = int(year)

    if quarter == "Q1":
        return pd.Timestamp(year=year, month=3, day=31)
    elif quarter == "Q2":
        return pd.Timestamp(year=year, month=6, day=30)
    elif quarter == "Q3":
        return pd.Timestamp(year=year, month=9, day=30)
    elif quarter == "Q4":
        return pd.Timestamp(year=year, month=12, day=31)

# %%
fact_status["churn_reference_date"] = fact_status["quarter"].apply(quarter_end_date)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fact_status["churn_reference_date"] = fact_status["quarter"].apply(quarter_end_date)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# ...

# %%
fact_status["quarter"].value_counts()
# Out:
# quarter
# Q3    7043
# Name: count, dtype: int64

# %%
fact_status["quarter"].dropna().unique()
# Out:
# array(['Q3'], dtype=object)
